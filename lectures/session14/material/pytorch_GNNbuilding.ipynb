# %% [markdown]
# # Build GNNs with Pytorch
# Using the esol_modified.csv data set to predict logP from structure

# %%
import math
import numpy
import pandas as pd
from pathlib import Path
import os
from rdkit import Chem

import torch
import torch.nn.functional as Fun
from torch.nn import Linear, Sequential, BatchNorm1d, ReLU
from torch_geometric.nn import GCNConv, GINConv, GATConv
from torch_geometric.loader import DataLoader
from torch_geometric.nn import global_mean_pool, global_add_pool
from torch_geometric.data import Data

# %% [markdown]
# First, load the esol data set from session11

# %%
df = pd.read_csv(os.path.join("..", "..", "session11", "material", "esol_modified.csv")).dropna(subset=["SMILES"])
# we will have trouble if the SMILES contains only a single atom (no graph can be constructed)
df = df.loc[df.SMILES != 'C']

# %% [markdown]
# Next, we encode the SMILES in the dataset into graph objects using RDKit

# %%
def atom_features(atom): # Create a tensor for atom features, length = 5
    return torch.tensor([
        atom.GetAtomicNum(),
        atom.GetTotalDegree(),
        atom.GetFormalCharge(),
        int(atom.GetIsAromatic()),
        atom.GetTotalNumHs(),
    ], dtype=torch.float)

def bond_features(bond): # Create a tensor for bond features, length = 6
    bt = bond.GetBondType()
    return torch.tensor([
        bt == Chem.rdchem.BondType.SINGLE,
        bt == Chem.rdchem.BondType.DOUBLE,
        bt == Chem.rdchem.BondType.TRIPLE,
        bt == Chem.rdchem.BondType.AROMATIC,
        bond.GetIsConjugated(),
        bond.IsInRing(),
    ], dtype=torch.float)

# %%
def smiles_to_graph(smiles, y):
    mol = Chem.MolFromSmiles(smiles) # Create a RDKit mol object from the smiles

    # Calculate atom features for all atoms in the molecule
    x = torch.stack([atom_features(atom) for atom in mol.GetAtoms()], dim=0)

    # Edges
    edge_index = []
    edge_attr = []
    
    # Iterate through all bonds in the molecule
    for bond in mol.GetBonds():
        i = bond.GetBeginAtomIdx()
        j = bond.GetEndAtomIdx()

        # Represent molecule as an undirected graph --> add both directions
        edge_index.append([i, j]) # left to right
        edge_index.append([j, i]) # right to left

        bf = bond_features(bond) # calculate bond features 
        edge_attr.append(bf)
        edge_attr.append(bf) # add two times, once for forward and once for backwards edge

    edge_index = torch.tensor(edge_index, dtype=torch.long).t().contiguous() 
    edge_attr  = torch.stack(edge_attr, dim=0)

    # Target property: logP
    y = torch.tensor([y], dtype=torch.float)
    
    # x: atom stack, y: logP
    return Data(x=x, edge_index=edge_index, edge_attr=edge_attr, y=y)

# %% [markdown]
# Obtain Graph representation of the data

# %%
graphs = [smiles_to_graph(row.SMILES, row.LogP) for _, row in df.iterrows()]

# %%
class GCNModel(torch.nn.Module):
    def __init__(self, dim_h=64): # dim_h: Size of hidden layer
        super().__init__()
        self.conv1 = GCNConv(5, dim_h) # first convolution layer: in_channels: 5, number of atom features
        self.conv2 = GCNConv(dim_h, dim_h) # second convolution layer
        self.lin = torch.nn.Linear(dim_h, 1) # output layer
        
    # Define how the data flows through the layers
    def forward(self, x, edge_index, batch):
        x = torch.relu(self.conv1(x, edge_index))  # input layer: convolution + activation function (ReLu)
        x = torch.relu(self.conv2(x, edge_index))  # hidden layer: convolution + activation function (ReLu)
        x = global_mean_pool(x, batch)             # pooling function
        return self.lin(x).squeeze(-1)

# %%
class GINModel(torch.nn.Module):
    def __init__(self, dim_h=64):
        super().__init__()

        nn1 = torch.nn.Sequential(
            torch.nn.Linear(5, dim_h),
            torch.nn.ReLU(),
            torch.nn.Linear(dim_h, dim_h)
        )
        nn2 = torch.nn.Sequential(
            torch.nn.Linear(dim_h, dim_h),
            torch.nn.ReLU(),
            torch.nn.Linear(dim_h, dim_h)
        )

        self.conv1 = GINConv(nn1)
        self.conv2 = GINConv(nn2)

        self.lin = torch.nn.Linear(dim_h, 1)

    def forward(self, x, edge_index, batch):
        x = torch.relu(self.conv1(x, edge_index))
        x = torch.relu(self.conv2(x, edge_index))
        x = global_mean_pool(x, batch) # try: global_add_pool(x, batch)
        return self.lin(x).squeeze(-1)

# %%
class GATModel(torch.nn.Module):
    def __init__(self, dim_h=64, heads=4):
        super().__init__()

        # Input layer
        self.conv1 = GATConv(
            in_channels=5,        # your atom feature size
            out_channels=dim_h,  # hidden dimension per head
            heads=heads,
            dropout=0.1,
            concat=True           # concatenates heads --> output = hidden * heads
        )

        # Second layer
        self.conv2 = GATConv(
            in_channels=dim_h * heads,
            out_channels=dim_h,
            heads=1,
            dropout=0.1,
            concat=False          # final output shape = (hidden,)
        )

        self.lin = torch.nn.Linear(dim_h, 1)

    def forward(self, x, edge_index, batch):
        x = torch.relu(self.conv1(x, edge_index))
        x = torch.relu(self.conv2(x, edge_index))
        x = global_mean_pool(x, batch)
        return self.lin(x).squeeze(-1)

# %%
def train(model, train_loader, val_loader, epochs=20, lr=1e-3):
    optimizer = torch.optim.Adam(model.parameters(), lr=lr) # lr: learning rate
    criterion = torch.nn.MSELoss() # loss function

    for epoch in range(epochs):
        model.train()
        train_losses = []

        for batch in train_loader:
            optimizer.zero_grad() # Reset gradients
            pred = model(batch.x, batch.edge_index, batch.batch) # predict on batch
            loss = criterion(pred, batch.y) # define criterion
            loss.backward() # computes the gradient of the loss
            optimizer.step() # Perform an optimization step
            train_losses.append(loss.item())

        val_loss = evaluate(model, val_loader) # evaluate re-trained model on validation data

        print(f"Epoch {epoch+1:02d} | "
              f"Train Loss = {sum(train_losses)/len(train_losses):.4f} | " # average train loss
              f"Val Loss = {val_loss:.4f}") 


def test(model, test_loader):
    test_loss = evaluate(model, test_loader)
    print(f"\nTest Loss: {test_loss:.4f}")

# %%
def create_splits(graphs, train_ratio=0.8, val_ratio=0.1, seed=42):
    torch.manual_seed(seed)
    graphs = graphs.copy()
    permutation = torch.randperm(len(graphs))
    graphs = [graphs[i] for i in permutation]

    n = len(graphs)
    n_train = int(n * train_ratio)
    n_val = int(n * val_ratio)

    train_graphs = graphs[:n_train]
    val_graphs   = graphs[n_train:n_train + n_val]
    test_graphs  = graphs[n_train + n_val:]

    return train_graphs, val_graphs, test_graphs

train_graphs, val_graphs, test_graphs = create_splits(graphs)

train_loader = DataLoader(train_graphs, batch_size=32, shuffle=True)
val_loader   = DataLoader(val_graphs, batch_size=32)
test_loader  = DataLoader(test_graphs, batch_size=32)

# %%
def evaluate(model, loader):
    model.eval()
    criterion = torch.nn.MSELoss()
    losses = []

    with torch.no_grad():
        for batch in loader:
            pred = model(batch.x, batch.edge_index, batch.batch)
            loss = criterion(pred, batch.y)
            losses.append(loss.item())

    return sum(losses) / len(losses)

# %% [markdown]
# Now, we load the data and train the GNNs

# %%
loader = DataLoader(graphs, batch_size=100, shuffle=True)

# %%
# training GCN for 10 epochs
gcn = GCNModel()
gin = GINModel()
gat = GATModel()

epochs = 100

print("\n=== Training GCN ===")
train(gcn, train_loader, val_loader, epochs=epochs)
test(gcn, test_loader)

print("\n=== Training GIN ===")
train(gin, train_loader, val_loader, epochs=epochs)
test(gin, test_loader)

print("\n=== Training GAT ===")
train(gat, train_loader, val_loader, epochs=epochs)
test(gat, test_loader)
# Out:
# === Training GCN ===
# Epoch 01 | Train Loss = 5.1606 | Val Loss = 4.9852
# Epoch 02 | Train Loss = 3.5849 | Val Loss = 5.2816
# Epoch 03 | Train Loss = 3.5483 | Val Loss = 5.0059
# Epoch 04 | Train Loss = 3.3125 | Val Loss = 5.1201
# Epoch 05 | Train Loss = 3.6308 | Val Loss = 4.9814
# Epoch 06 | Train Loss = 3.2428 | Val Loss = 5.0482
# Epoch 07 | Train Loss = 3.1845 | Val Loss = 5.0013
# Epoch 08 | Train Loss = 3.2431 | Val Loss = 4.9134
# Epoch 09 | Train Loss = 3.1069 | Val Loss = 5.0049
# Epoch 10 | Train Loss = 3.1410 | Val Loss = 4.7879
# Epoch 11 | Train Loss = 3.1299 | Val Loss = 4.7976
# Epoch 12 | Train Loss = 3.1025 | Val Loss = 4.6185
# Epoch 13 | Train Loss = 3.0160 | Val Loss = 4.5971
# Epoch 14 | Train Loss = 3.0754 | Val Loss = 4.5244
# Epoch 15 | Train Loss = 2.9497 | Val Loss = 4.7907
# Epoch 16 | Train Loss = 3.1708 | Val Loss = 4.5329
# Epoch 17 | Train Loss = 2.9750 | Val Loss = 4.5853
# Epoch 18 | Train Loss = 2.9326 | Val Loss = 4.4285
# Epoch 19 | Train Loss = 2.9651 | Val Loss = 4.4339
# Epoch 20 | Train Loss = 2.8980 | Val Loss = 4.4485
# Epoch 21 | Train Loss = 2.9912 | Val Loss = 4.3908
# Epoch 22 | Train Loss = 3.0259 | Val Loss = 4.3796
# Epoch 23 | Train Loss = 2.9304 | Val Loss = 4.3184
# Epoch 24 | Train Loss = 3.0194 | Val Loss = 4.2795
# Epoch 25 | Train Loss = 2.8640 | Val Loss = 4.2168
# Epoch 26 | Train Loss = 2.8790 | Val Loss = 4.2170
# Epoch 27 | Train Loss = 2.8399 | Val Loss = 4.2723
# Epoch 28 | Train Loss = 2.8327 | Val Loss = 4.1883
# Epoch 29 | Train Loss = 2.8620 | Val Loss = 4.1756
# Epoch 30 | Train Loss = 2.7562 | Val Loss = 4.0381
# Epoch 31 | Train Loss = 2.7631 | Val Loss = 3.9712
# Epoch 32 | Train Loss = 3.0758 | Val Loss = 3.9009
# Epoch 33 | Train Loss = 3.1742 | Val Loss = 3.8836
# Epoch 34 | Train Loss = 2.6688 | Val Loss = 3.8294
# Epoch 35 | Train Loss = 2.6040 | Val Loss = 3.8218
# Epoch 36 | Train Loss = 2.5635 | Val Loss = 3.7190
# Epoch 37 | Train Loss = 2.5929 | Val Loss = 3.6670
# Epoch 38 | Train Loss = 2.4963 | Val Loss = 3.7555
# Epoch 39 | Train Loss = 2.6107 | Val Loss = 3.4951
# Epoch 40 | Train Loss = 2.5791 | Val Loss = 3.4737
# Epoch 41 | Train Loss = 2.4801 | Val Loss = 3.5670
# Epoch 42 | Train Loss = 2.4601 | Val Loss = 3.4128
# Epoch 43 | Train Loss = 2.4543 | Val Loss = 3.3346
# Epoch 44 | Train Loss = 2.4352 | Val Loss = 3.3298
# Epoch 45 | Train Loss = 2.5200 | Val Loss = 3.4762
# Epoch 46 | Train Loss = 2.3740 | Val Loss = 3.1414
# Epoch 47 | Train Loss = 2.3231 | Val Loss = 3.1900
# Epoch 48 | Train Loss = 2.3621 | Val Loss = 3.1577
# Epoch 49 | Train Loss = 2.3917 | Val Loss = 3.3040
# Epoch 50 | Train Loss = 2.3697 | Val Loss = 3.0094
# Epoch 51 | Train Loss = 2.2264 | Val Loss = 3.0271
# Epoch 52 | Train Loss = 2.2330 | Val Loss = 2.9269
# Epoch 53 | Train Loss = 2.2590 | Val Loss = 2.8352
# Epoch 54 | Train Loss = 2.1990 | Val Loss = 2.8875
# Epoch 55 | Train Loss = 2.1759 | Val Loss = 2.7720
# Epoch 56 | Train Loss = 2.1555 | Val Loss = 2.8948
# Epoch 57 | Train Loss = 2.1700 | Val Loss = 2.7585
# Epoch 58 | Train Loss = 2.1596 | Val Loss = 2.6725
# Epoch 59 | Train Loss = 2.1707 | Val Loss = 2.6799
# Epoch 60 | Train Loss = 2.1114 | Val Loss = 2.6121
# Epoch 61 | Train Loss = 2.1898 | Val Loss = 2.6130
# Epoch 62 | Train Loss = 2.1324 | Val Loss = 2.6716
# Epoch 63 | Train Loss = 2.0128 | Val Loss = 2.5342
# Epoch 64 | Train Loss = 2.0555 | Val Loss = 2.5880
# Epoch 65 | Train Loss = 2.0739 | Val Loss = 2.4362
# Epoch 66 | Train Loss = 2.0229 | Val Loss = 2.4515
# Epoch 67 | Train Loss = 2.0030 | Val Loss = 2.4283
# Epoch 68 | Train Loss = 2.0861 | Val Loss = 2.3891
# Epoch 69 | Train Loss = 2.0030 | Val Loss = 2.4897
# Epoch 70 | Train Loss = 1.9886 | Val Loss = 2.3154
# Epoch 71 | Train Loss = 2.0046 | Val Loss = 2.5523
# Epoch 72 | Train Loss = 1.9730 | Val Loss = 2.2756
# Epoch 73 | Train Loss = 2.2360 | Val Loss = 2.6214
# Epoch 74 | Train Loss = 1.9778 | Val Loss = 2.2904
# Epoch 75 | Train Loss = 1.9063 | Val Loss = 2.4382
# Epoch 76 | Train Loss = 1.9422 | Val Loss = 2.2048
# Epoch 77 | Train Loss = 1.9296 | Val Loss = 2.3047
# Epoch 78 | Train Loss = 1.9520 | Val Loss = 2.1052
# Epoch 79 | Train Loss = 1.8972 | Val Loss = 2.2867
# Epoch 80 | Train Loss = 1.8974 | Val Loss = 2.0732
# Epoch 81 | Train Loss = 1.8499 | Val Loss = 2.0422
# Epoch 82 | Train Loss = 1.8142 | Val Loss = 2.0939
# Epoch 83 | Train Loss = 1.9064 | Val Loss = 2.0556
# Epoch 84 | Train Loss = 1.7653 | Val Loss = 1.9989
# Epoch 85 | Train Loss = 1.7991 | Val Loss = 2.0139
# Epoch 86 | Train Loss = 1.7234 | Val Loss = 1.9797
# Epoch 87 | Train Loss = 1.7901 | Val Loss = 1.9990
# Epoch 88 | Train Loss = 1.7932 | Val Loss = 1.9101
# Epoch 89 | Train Loss = 1.7678 | Val Loss = 1.9779
# Epoch 90 | Train Loss = 1.6805 | Val Loss = 1.9479
# Epoch 91 | Train Loss = 1.7465 | Val Loss = 1.8328
# Epoch 92 | Train Loss = 1.9809 | Val Loss = 1.9216
# Epoch 93 | Train Loss = 1.7760 | Val Loss = 2.2688
# Epoch 94 | Train Loss = 1.8113 | Val Loss = 1.8530
# Epoch 95 | Train Loss = 1.6536 | Val Loss = 2.1950
# Epoch 96 | Train Loss = 1.8183 | Val Loss = 2.1957
# Epoch 97 | Train Loss = 1.7654 | Val Loss = 1.7948
# Epoch 98 | Train Loss = 1.6386 | Val Loss = 1.9370
# Epoch 99 | Train Loss = 1.6231 | Val Loss = 1.9055
# Epoch 100 | Train Loss = 1.6117 | Val Loss = 1.7932
#
# Test Loss: 1.4488
#
# === Training GIN ===
# Epoch 01 | Train Loss = 3.5613 | Val Loss = 4.1971
# Epoch 02 | Train Loss = 3.6228 | Val Loss = 4.3790
# Epoch 03 | Train Loss = 2.9245 | Val Loss = 4.0230
# Epoch 04 | Train Loss = 2.8024 | Val Loss = 4.1737
# Epoch 05 | Train Loss = 2.8068 | Val Loss = 3.9063
# Epoch 06 | Train Loss = 2.7439 | Val Loss = 3.7173
# Epoch 07 | Train Loss = 2.6432 | Val Loss = 3.6554
# Epoch 08 | Train Loss = 2.4302 | Val Loss = 3.3482
# Epoch 09 | Train Loss = 2.2703 | Val Loss = 3.1826
# Epoch 10 | Train Loss = 2.2967 | Val Loss = 3.2248
# Epoch 11 | Train Loss = 2.1229 | Val Loss = 2.8652
# Epoch 12 | Train Loss = 2.1108 | Val Loss = 2.8304
# Epoch 13 | Train Loss = 2.0667 | Val Loss = 2.9027
# Epoch 14 | Train Loss = 2.0288 | Val Loss = 2.4147
# Epoch 15 | Train Loss = 2.1994 | Val Loss = 2.9083
# Epoch 16 | Train Loss = 1.8903 | Val Loss = 2.2093
# Epoch 17 | Train Loss = 1.7715 | Val Loss = 2.0300
# Epoch 18 | Train Loss = 1.9919 | Val Loss = 2.3212
# Epoch 19 | Train Loss = 1.8290 | Val Loss = 1.9279
# Epoch 20 | Train Loss = 1.6403 | Val Loss = 1.7620
# Epoch 21 | Train Loss = 1.5841 | Val Loss = 2.0057
# Epoch 22 | Train Loss = 1.5381 | Val Loss = 1.6563
# Epoch 23 | Train Loss = 1.5258 | Val Loss = 1.6352
# Epoch 24 | Train Loss = 1.4945 | Val Loss = 2.1645
# Epoch 25 | Train Loss = 1.6534 | Val Loss = 1.9166
# Epoch 26 | Train Loss = 1.5987 | Val Loss = 1.4620
# Epoch 27 | Train Loss = 1.4004 | Val Loss = 1.4395
# Epoch 28 | Train Loss = 1.3525 | Val Loss = 1.8149
# Epoch 29 | Train Loss = 1.3754 | Val Loss = 1.7567
# Epoch 30 | Train Loss = 1.3481 | Val Loss = 1.4413
# Epoch 31 | Train Loss = 1.3694 | Val Loss = 1.7834
# Epoch 32 | Train Loss = 1.3541 | Val Loss = 1.4517
# Epoch 33 | Train Loss = 1.3450 | Val Loss = 1.6678
# Epoch 34 | Train Loss = 1.3438 | Val Loss = 1.4779
# Epoch 35 | Train Loss = 1.3338 | Val Loss = 1.4234
# Epoch 36 | Train Loss = 1.2399 | Val Loss = 1.2467
# Epoch 37 | Train Loss = 1.2952 | Val Loss = 2.0983
# Epoch 38 | Train Loss = 1.3608 | Val Loss = 1.4163
# Epoch 39 | Train Loss = 1.3062 | Val Loss = 2.0615
# Epoch 40 | Train Loss = 1.3719 | Val Loss = 1.4364
# Epoch 41 | Train Loss = 1.3194 | Val Loss = 1.6212
# Epoch 42 | Train Loss = 1.2025 | Val Loss = 1.4204
# Epoch 43 | Train Loss = 1.2829 | Val Loss = 1.1702
# Epoch 44 | Train Loss = 1.2636 | Val Loss = 1.4421
# Epoch 45 | Train Loss = 1.2564 | Val Loss = 1.6868
# Epoch 46 | Train Loss = 1.2886 | Val Loss = 1.1014
# Epoch 47 | Train Loss = 1.2494 | Val Loss = 1.4799
# Epoch 48 | Train Loss = 1.2639 | Val Loss = 1.2810
# Epoch 49 | Train Loss = 1.2077 | Val Loss = 1.6429
# Epoch 50 | Train Loss = 1.2092 | Val Loss = 1.4094
# Epoch 51 | Train Loss = 1.2879 | Val Loss = 1.1359
# Epoch 52 | Train Loss = 1.2158 | Val Loss = 1.2446
# Epoch 53 | Train Loss = 1.2068 | Val Loss = 1.1528
# Epoch 54 | Train Loss = 1.1822 | Val Loss = 1.1968
# Epoch 55 | Train Loss = 1.2567 | Val Loss = 1.1966
# Epoch 56 | Train Loss = 1.1532 | Val Loss = 1.3037
# Epoch 57 | Train Loss = 1.2579 | Val Loss = 1.2596
# Epoch 58 | Train Loss = 1.1482 | Val Loss = 1.2198
# Epoch 59 | Train Loss = 1.1412 | Val Loss = 1.8314
# Epoch 60 | Train Loss = 1.2065 | Val Loss = 1.0872
# Epoch 61 | Train Loss = 1.2467 | Val Loss = 1.3597
# Epoch 62 | Train Loss = 1.7143 | Val Loss = 1.1989
# Epoch 63 | Train Loss = 1.3229 | Val Loss = 1.9386
# Epoch 64 | Train Loss = 1.3972 | Val Loss = 1.4665
# Epoch 65 | Train Loss = 1.1393 | Val Loss = 1.2937
# Epoch 66 | Train Loss = 1.0863 | Val Loss = 1.1639
# Epoch 67 | Train Loss = 1.0455 | Val Loss = 1.3634
# Epoch 68 | Train Loss = 1.0991 | Val Loss = 1.2170
# Epoch 69 | Train Loss = 1.0749 | Val Loss = 1.6973
# Epoch 70 | Train Loss = 1.1194 | Val Loss = 1.2185
# Epoch 71 | Train Loss = 1.1537 | Val Loss = 1.0158
# Epoch 72 | Train Loss = 1.0417 | Val Loss = 1.0588
# Epoch 73 | Train Loss = 1.1212 | Val Loss = 1.1950
# Epoch 74 | Train Loss = 1.1373 | Val Loss = 1.0177
# Epoch 75 | Train Loss = 1.1147 | Val Loss = 1.1966
# Epoch 76 | Train Loss = 1.0953 | Val Loss = 1.1625
# Epoch 77 | Train Loss = 1.0642 | Val Loss = 0.9342
# Epoch 78 | Train Loss = 1.1375 | Val Loss = 1.0226
# Epoch 79 | Train Loss = 1.0980 | Val Loss = 1.2677
# Epoch 80 | Train Loss = 1.0296 | Val Loss = 1.5344
# Epoch 81 | Train Loss = 1.0367 | Val Loss = 1.1559
# Epoch 82 | Train Loss = 1.1399 | Val Loss = 1.2294
# Epoch 83 | Train Loss = 1.0615 | Val Loss = 1.0618
# Epoch 84 | Train Loss = 1.0801 | Val Loss = 1.1595
# Epoch 85 | Train Loss = 1.0693 | Val Loss = 0.9663
# Epoch 86 | Train Loss = 1.0027 | Val Loss = 1.2527
# Epoch 87 | Train Loss = 1.0203 | Val Loss = 1.0736
# Epoch 88 | Train Loss = 1.0268 | Val Loss = 1.0903
# Epoch 89 | Train Loss = 1.0861 | Val Loss = 1.0040
# Epoch 90 | Train Loss = 1.1302 | Val Loss = 1.1780
# Epoch 91 | Train Loss = 1.0130 | Val Loss = 1.3649
# Epoch 92 | Train Loss = 1.0800 | Val Loss = 1.0793
# Epoch 93 | Train Loss = 1.0012 | Val Loss = 1.1459
# Epoch 94 | Train Loss = 0.9923 | Val Loss = 0.9598
# Epoch 95 | Train Loss = 1.0442 | Val Loss = 1.0976
# Epoch 96 | Train Loss = 1.2707 | Val Loss = 1.0586
# Epoch 97 | Train Loss = 0.9819 | Val Loss = 0.8831
# Epoch 98 | Train Loss = 0.9863 | Val Loss = 0.9669
# Epoch 99 | Train Loss = 1.0211 | Val Loss = 0.9048
# Epoch 100 | Train Loss = 1.0317 | Val Loss = 1.0433
#
# Test Loss: 1.2346
#
# === Training GAT ===
# Epoch 01 | Train Loss = 5.0245 | Val Loss = 5.1696
# Epoch 02 | Train Loss = 3.6199 | Val Loss = 5.0150
# Epoch 03 | Train Loss = 3.3173 | Val Loss = 4.9285
# Epoch 04 | Train Loss = 3.3644 | Val Loss = 4.7728
# Epoch 05 | Train Loss = 3.2234 | Val Loss = 4.6842
# Epoch 06 | Train Loss = 3.1705 | Val Loss = 4.5735
# Epoch 07 | Train Loss = 3.0355 | Val Loss = 4.3508
# Epoch 08 | Train Loss = 2.8854 | Val Loss = 4.3798
# Epoch 09 | Train Loss = 2.7948 | Val Loss = 4.1512
# Epoch 10 | Train Loss = 2.7766 | Val Loss = 4.1562
# Epoch 11 | Train Loss = 2.6661 | Val Loss = 3.8536
# Epoch 12 | Train Loss = 2.6970 | Val Loss = 4.0506
# Epoch 13 | Train Loss = 2.5661 | Val Loss = 3.5328
# Epoch 14 | Train Loss = 2.3864 | Val Loss = 3.7606
# Epoch 15 | Train Loss = 2.3488 | Val Loss = 3.5107
# Epoch 16 | Train Loss = 2.2501 | Val Loss = 3.0153
# Epoch 17 | Train Loss = 2.1699 | Val Loss = 2.8782
# Epoch 18 | Train Loss = 2.0464 | Val Loss = 2.7572
# Epoch 19 | Train Loss = 2.0410 | Val Loss = 2.5178
# Epoch 20 | Train Loss = 2.0127 | Val Loss = 2.4207
# Epoch 21 | Train Loss = 1.8312 | Val Loss = 2.1805
# Epoch 22 | Train Loss = 1.7457 | Val Loss = 2.1556
# Epoch 23 | Train Loss = 1.7225 | Val Loss = 2.3321
# Epoch 24 | Train Loss = 1.6921 | Val Loss = 2.2546
# Epoch 25 | Train Loss = 1.7401 | Val Loss = 1.8860
# Epoch 26 | Train Loss = 1.6563 | Val Loss = 1.9619
# Epoch 27 | Train Loss = 1.5991 | Val Loss = 2.0136
# Epoch 28 | Train Loss = 1.6263 | Val Loss = 1.6559
# Epoch 29 | Train Loss = 1.5138 | Val Loss = 2.2807
# Epoch 30 | Train Loss = 1.5526 | Val Loss = 1.8122
# Epoch 31 | Train Loss = 1.4047 | Val Loss = 1.8699
# Epoch 32 | Train Loss = 1.4893 | Val Loss = 2.0306
# Epoch 33 | Train Loss = 1.4281 | Val Loss = 1.4321
# Epoch 34 | Train Loss = 1.3763 | Val Loss = 1.7792
# Epoch 35 | Train Loss = 1.4061 | Val Loss = 1.5389
# Epoch 36 | Train Loss = 1.3321 | Val Loss = 1.7481
# Epoch 37 | Train Loss = 1.4385 | Val Loss = 1.3703
# Epoch 38 | Train Loss = 1.3918 | Val Loss = 1.8723
# Epoch 39 | Train Loss = 1.3941 | Val Loss = 1.9060
# Epoch 40 | Train Loss = 1.3257 | Val Loss = 1.5244
# Epoch 41 | Train Loss = 1.3552 | Val Loss = 1.2315
# Epoch 42 | Train Loss = 1.3490 | Val Loss = 1.3042
# Epoch 43 | Train Loss = 1.2846 | Val Loss = 1.3379
# Epoch 44 | Train Loss = 1.2803 | Val Loss = 1.5478
# Epoch 45 | Train Loss = 1.2720 | Val Loss = 1.2971
# Epoch 46 | Train Loss = 1.2288 | Val Loss = 1.2955
# Epoch 47 | Train Loss = 1.2316 | Val Loss = 1.1545
# Epoch 48 | Train Loss = 1.1800 | Val Loss = 1.1995
# Epoch 49 | Train Loss = 1.1603 | Val Loss = 1.1995
# Epoch 50 | Train Loss = 1.2296 | Val Loss = 1.3970
# Epoch 51 | Train Loss = 1.2784 | Val Loss = 1.2332
# Epoch 52 | Train Loss = 1.2731 | Val Loss = 1.3463
# Epoch 53 | Train Loss = 1.1876 | Val Loss = 1.2374
# Epoch 54 | Train Loss = 1.2848 | Val Loss = 1.1340
# Epoch 55 | Train Loss = 1.1505 | Val Loss = 1.2731
# Epoch 56 | Train Loss = 1.1974 | Val Loss = 1.1406
# Epoch 57 | Train Loss = 1.1353 | Val Loss = 1.1704
# Epoch 58 | Train Loss = 1.1594 | Val Loss = 1.1084
# Epoch 59 | Train Loss = 1.0874 | Val Loss = 1.2365
# Epoch 60 | Train Loss = 1.0639 | Val Loss = 1.2876
# Epoch 61 | Train Loss = 1.1199 | Val Loss = 1.0972
# Epoch 62 | Train Loss = 1.1834 | Val Loss = 1.1093
# Epoch 63 | Train Loss = 1.2909 | Val Loss = 1.1152
# Epoch 64 | Train Loss = 1.1422 | Val Loss = 1.5361
# Epoch 65 | Train Loss = 1.1941 | Val Loss = 1.2102
# Epoch 66 | Train Loss = 1.2891 | Val Loss = 1.3059
# Epoch 67 | Train Loss = 1.1330 | Val Loss = 1.2855
# Epoch 68 | Train Loss = 1.1397 | Val Loss = 1.3655
# Epoch 69 | Train Loss = 1.1583 | Val Loss = 1.5686
# Epoch 70 | Train Loss = 1.1733 | Val Loss = 1.0190
# Epoch 71 | Train Loss = 1.0890 | Val Loss = 1.0857
# Epoch 72 | Train Loss = 1.1081 | Val Loss = 1.0197
# Epoch 73 | Train Loss = 1.0950 | Val Loss = 1.2235
# Epoch 74 | Train Loss = 1.1116 | Val Loss = 1.0402
# Epoch 75 | Train Loss = 1.1814 | Val Loss = 1.4463
# Epoch 76 | Train Loss = 1.0487 | Val Loss = 1.1958
# Epoch 77 | Train Loss = 1.0947 | Val Loss = 1.0593
# Epoch 78 | Train Loss = 1.0591 | Val Loss = 1.0828
# Epoch 79 | Train Loss = 1.0477 | Val Loss = 1.2718
# Epoch 80 | Train Loss = 1.0690 | Val Loss = 1.0486
# Epoch 81 | Train Loss = 1.1746 | Val Loss = 0.9743
# Epoch 82 | Train Loss = 1.0737 | Val Loss = 1.1029
# Epoch 83 | Train Loss = 1.0074 | Val Loss = 1.2733
# Epoch 84 | Train Loss = 1.1474 | Val Loss = 1.0240
# Epoch 85 | Train Loss = 1.2739 | Val Loss = 1.0036
# Epoch 86 | Train Loss = 1.1051 | Val Loss = 1.0474
# Epoch 87 | Train Loss = 1.1709 | Val Loss = 1.0344
# Epoch 88 | Train Loss = 1.0997 | Val Loss = 1.1018
# Epoch 89 | Train Loss = 1.0250 | Val Loss = 0.9838
# Epoch 90 | Train Loss = 1.0278 | Val Loss = 1.0700
# Epoch 91 | Train Loss = 1.0374 | Val Loss = 1.0304
# Epoch 92 | Train Loss = 1.0020 | Val Loss = 0.9381
# Epoch 93 | Train Loss = 1.0616 | Val Loss = 0.9949
# Epoch 94 | Train Loss = 0.9864 | Val Loss = 0.9107
# Epoch 95 | Train Loss = 0.9817 | Val Loss = 0.9446
# Epoch 96 | Train Loss = 0.9789 | Val Loss = 0.9124
# Epoch 97 | Train Loss = 0.9263 | Val Loss = 0.9724
# Epoch 98 | Train Loss = 0.9963 | Val Loss = 1.0407
# Epoch 99 | Train Loss = 0.9970 | Val Loss = 1.0866
# Epoch 100 | Train Loss = 1.0106 | Val Loss = 0.9921
#
# Test Loss: 1.0059

# %%
import matplotlib.pyplot as plt
def parity_plot(model, test_loader, title="Parity Plot (Test Set)"):
    model.eval()
    preds = []
    trues = []

    with torch.no_grad():
        for batch in test_loader:
            pred = model(batch.x, batch.edge_index, batch.batch)

            # Ensure correct shapes
            pred = pred.view(-1).cpu()
            y = batch.y.view(-1).cpu()

            preds.append(pred)
            trues.append(y)

    preds = torch.cat(preds).numpy()
    trues = torch.cat(trues).numpy()

    # Parity plot
    plt.figure(figsize=(5,5))
    plt.scatter(trues, preds, alpha=0.6)
    plt.plot([trues.min(), trues.max()],
             [trues.min(), trues.max()],
             color='red', linestyle='--', linewidth=2)

    plt.xlabel("True logP")
    plt.ylabel("Predicted logP")
    plt.title(title)
    plt.tight_layout()
    plt.show()

# Usage:

# %%
parity_plot(gcn, test_loader)

# %%
parity_plot(gin, test_loader)

# %%
parity_plot(gat, test_loader)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
