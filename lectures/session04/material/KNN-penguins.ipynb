# %% [markdown]
# # KNN Classifier for penguins
#
# The following exercise aims to apply a KNN classifier to distinguish different species of penguins based on the Palmer Penguins dataset imported via Seaborn.

# %% [markdown]
# #### 1) Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.pipeline import Pipeline

# %% [markdown]
# #### 2) Load data

# %%
# Load penguins dataset
penguins = sns.load_dataset("penguins")

# Show first rows
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# #### 3) Inspect the data
# Apply the fundamental tools of EDA (summary statistics, visualisation!) and see which features might be well suited for classification!

# %%
sns.pairplot(data=penguins, hue="species")

# %% [markdown]
# #### 4) Data cleaning
# Drop rows with missing numerical values or missing labels (Hint: ideally with subset! Don't forget to comment!), then separate the features (X) and targets (y).

# %%
# NaNs are super bad for KNN ...drop them :)
penguins = penguins.dropna()
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 333 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            333 non-null    object
#  1   island             333 non-null    object
#  2   bill_length_mm     333 non-null    float64
#  3   bill_depth_mm      333 non-null    float64
#  4   flipper_length_mm  333 non-null    float64
#  5   body_mass_g        333 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 20.8+ KB

# %%
# Features (X) and target (y)
X = penguins[[
    "bill_length_mm",
    "bill_depth_mm",
    "flipper_length_mm",
    "body_mass_g"
]]

y = penguins["species"]

# %% [markdown]
# #### 5) Train-test split
# Check later, how a different split ratio influences the prediction!

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.3,
    random_state=42,
    stratify=y
)

# %% [markdown]
# #### 6) Feature scaling
# kNN = distance based algorithm, scaling is essential!

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[ 0.16349714, -1.99829162,  0.8343084 ,  1.08259122],
#        [ 1.05195351,  0.02276947, -0.24366123, -0.69245742],
#        [ 2.15799103, -0.12881012,  1.91227804,  1.7054153 ],
#        [ 1.16074408, -0.78565497,  1.48109019,  1.89226252],
#        [-0.97880391,  1.99330403, -0.74671373, -0.5367514 ],
#        [-0.61616865, -0.02775706, -1.0341723 , -0.94158705],
#        [-0.6886957 , -0.07828359, -0.60298445, -1.03501066],
#        [ 2.53875804,  0.2754021 , -1.46536016, -0.66131621],
#        [-1.21451682,  0.2754021 , -0.74671373, -1.09729307],
#        [ 0.4717371 ,  0.2754021 , -0.60298445, -0.5367514 ],
#        [-1.4683615 , -0.33091623, -0.81857837, -1.47098752],
#        [ 1.01568998, -1.13934066,  1.04990233,  0.64661436],
#        [ 0.6167912 , -1.34144677,  0.76244376,  0.61547315],
#        [-0.07221578, -1.69513246,  1.12176697,  0.83346158],
#        [ 1.01568998, -0.63407539,  1.69668411,  1.82998011],
#        [-0.21726988, -1.54355288,  0.54684983,  0.58433195],
#        [ 0.19976066, -1.44249982,  0.61871448,  0.2106375 ],
#        [-0.27166516,  1.74067139, -0.31552588,  0.33520232],
#        [-0.88814509,  0.73014085, -1.46536016, -0.59903381],
#        [ 0.50800063, -1.49302635,  0.97803769,  0.77117917],
#        [ 0.326683  , -1.54355288,  1.26549626,  0.58433195],
#        [-1.37770268, -0.12881012, -0.45925516, -1.12843428],
#        [ 1.14261232,  1.3869857 , -0.31552588, -1.15957548],
#        [ 0.27228771, -0.12881012, -0.38739052, -0.91044585],
#        [ 1.07008527, -0.58354886,  0.8343084 ,  1.45628567],
#        [-0.77935452,  0.32592863, -0.60298445,  0.02379028],
#        [ 0.7618453 , -1.49302635,  0.61871448,  0.45976713],
#        [ 1.12448056, -1.49302635,  1.19363162,  1.82998011],
#        [-1.54088855, -0.53302233, -0.45925516, -1.09729307],
#        [-1.06946272, -0.38144275, -0.24366123, -0.50561019],
#        [ 0.97942646, -0.73512844,  1.04990233,  0.86460279],
#        [-1.14198977,  0.73014085, -1.5372248 , -0.78588103],
#        [-0.94254038, -0.02775706, -1.5372248 , -0.5367514 ],
#        [ 0.21789243, -0.33091623, -0.74671373, -1.22185789],
#        [-0.79748628,  0.78066737, -0.81857837,  0.45976713],
#        [-0.63430042,  0.32592863, -1.0341723 , -1.2841403 ],
#        [ 0.21789243, -0.73512844,  0.97803769,  1.33172085],
#        [ 0.21789243, -0.43196928,  1.55295483,  2.14139216],
#        [ 0.29041948,  1.08382654, -0.5311198 , -0.87930464],
#        [-1.05133096,  1.3869857 , -0.81857837, -0.41218658],
#        [ 0.01844304,  1.23540612, -0.38739052,  0.2106375 ],
#        [-1.70407441,  1.9427775 , -0.24366123,  0.2106375 ],
#        [-1.14198977, -0.63407539, -1.32163087, -1.43984632],
#        [ 0.87063588, -0.53302233,  1.48109019,  2.20367456],
#        [-0.1084793 , -1.44249982,  1.19363162,  0.45976713],
#        [-1.9035238 ,  0.88172043, -0.81857837, -0.78588103]])

# %% [markdown]
# #### 7) Train the model
# For a start, use k=5, then try higher and lower values and see how the prediction changes.

# %%
knn = KNeighborsClassifier(n_neighbors=5)

knn.fit(X_train_scaled, y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# #### 8) Predictions
# Predict the label for both the training and the test set!

# %%
y_test_pred = knn.predict(X_test_scaled)
y_train_pred = knn.predict(X_train_scaled)

# %% [markdown]
# #### 9) Evaluation of the model

# %%
print("Accuracy on training set:", accuracy_score(y_train, y_train_pred))
print("Accuracy on test set:", accuracy_score(y_test, y_test_pred))
print("\n------------------------------------------------")
print("\nClassification Report:\n")
print(classification_report(y_test, y_test_pred))
# Out:
# Accuracy on training set: 0.9957081545064378
# Accuracy on test set: 1.0
#
# ------------------------------------------------
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#       Adelie       1.00      1.00      1.00        44
#    Chinstrap       1.00      1.00      1.00        20
#       Gentoo       1.00      1.00      1.00        36
#
#     accuracy                           1.00       100
#    macro avg       1.00      1.00      1.00       100
# weighted avg       1.00      1.00      1.00       100

# %%
cm = confusion_matrix(y_test, y_test_pred)

plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt="d",
            xticklabels=knn.classes_,
            yticklabels=knn.classes_,
            cmap="Blues")

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# #### 10) Explore
# - Try different k
# - See what happens if you omit the scaling

# %% [markdown]
# #### 11) Predict labels for unknown data
#
# - Predict the labels for the (generated) penguins in "penguins_mystery.csv".
# - Invent your own penguin and see which class it would be according to the KNN. You can exaggerate a bit ;-)
# - Bonus: Use an AI tool to create an image for your fantasy penguin and share it on the teams channel.

# %%
penguins_to_predict = pd.read_csv("penguins_mystery.csv")
# make sure there is no NaN:
print(penguins_to_predict.info())
penguins_to_predict.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 20 non-null     int64
#  1   island             20 non-null     object
#  2   bill_length_mm     20 non-null     float64
#  3   bill_depth_mm      20 non-null     float64
#  4   flipper_length_mm  20 non-null     int64
#  5   body_mass_g        20 non-null     int64
#  6   sex                20 non-null     object
# dtypes: float64(2), int64(3), object(2)
# memory usage: 1.2+ KB
# None
#    id  island  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# 0   1  Biscoe            50.4           14.4                211         4857
# 1   2  Biscoe            38.7           20.3                201         2783
# 2   3   Dream            45.5           17.1                199         3553
# 3   4   Dream            38.5           18.6                192         3735
# 4   5  Biscoe            36.1           18.5                183         3806
#
#       sex
# 0    male
# 1  female
# 2    male
# 3    male
# 4    male

# %%
# Extract and scale numerical features
X_to_predict = penguins_to_predict[["bill_length_mm", "bill_depth_mm", "flipper_length_mm", "body_mass_g"]]
X_to_predict_scaled = scaler.transform(X_to_predict)

# %%
penguins_to_predict["predicted_species"] = knn.predict(X_to_predict_scaled)
penguins_to_predict
# Out:
#     id     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    1     Biscoe            50.4           14.4                211
# 1    2     Biscoe            38.7           20.3                201
# 2    3      Dream            45.5           17.1                199
# 3    4      Dream            38.5           18.6                192
# 4    5     Biscoe            36.1           18.5                183
# 5    6     Biscoe            48.4           16.5                223
# 6    7      Dream            51.6           19.9                185
# 7    8      Dream            48.6           21.1                194
# 8    9     Biscoe            47.6           13.6                213
# 9   10      Dream            39.1           19.3                182
# 10  11      Dream            40.4           17.1                195
# 11  12     Biscoe            52.1           15.4                224
# 12  13     Biscoe            45.2           13.9                215
# 13  14     Biscoe            45.6           14.2                214
# 14  15      Dream            38.6           19.2                194
# 15  16      Dream            47.9           19.4                207
# 16  17  Torgersen            41.9           17.8                198
# 17  18      Dream            35.2           18.7                183
# 18  19      Dream            47.7           18.9                185
# 19  20      Dream            40.3           19.1                189
#
#     body_mass_g     sex predicted_species
# 0          4857    male            Gentoo
# 1          2783  female            Adelie
# 2          3553    male         Chinstrap
# 3          3735    male            Adelie
# 4          3806    male            Adelie
# 5          5551    male            Gentoo
# 6          4030  female         Chinstrap
# 7          3994    male         Chinstrap
# 8          5113    male            Gentoo
# 9          3588    male            Adelie
# 10         4073    male            Adelie
# 11         4954    male            Gentoo
# 12         5056    male            Gentoo
# 13         3723  female            Gentoo
# 14         3511    male            Adelie
# 15         3452    male         Chinstrap
# 16         2858  female            Adelie
# 17         3260  female            Adelie
# 18         3504  female         Chinstrap
# 19         3161  female            Adelie

# %%
# Invent new penguins: 
new_penguins = pd.DataFrame(
    {
    "bill_length_mm": [197.2, 45.3, 56.6],
    "bill_depth_mm": [15.2, 22.4, 19.1],
    "flipper_length_mm": [220, 238, 289],
    "body_mass_g": [12014, 2907, 6781]
    }
)
new_penguins
# Out:
#    bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0           197.2           15.2                220        12014
# 1            45.3           22.4                238         2907
# 2            56.6           19.1                289         6781

# %%
# scale unknown penguins
X_new_scaled = scaler.transform(new_penguins)
new_penguins["predicted_label"] = knn.predict(X_new_scaled)
new_penguins
# Out:
#    bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# 0           197.2           15.2                220        12014
# 1            45.3           22.4                238         2907
# 2            56.6           19.1                289         6781
#
#   predicted_label
# 0          Gentoo
# 1       Chinstrap
# 2          Gentoo

# %% [markdown]
# The first new one was visualised using Dall-E :)
